# %%
import os 
import numpy as np

import argparse
import socket
import time
import sys

import torchvision
from torchvision import transforms
from torchvision.models import resnet50
from sklearn.metrics import f1_score
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

import copy

# %%
print(torch.__version__)
# Out:
# 1.8.1+cu111

# %%
parser = argparse.ArgumentParser('argument for training')
# dataset
parser.add_argument('--model', type=str, default='resnet50')

# specify folder
parser.add_argument('--model_path', type=str, default='../checkpoint_0302/ours_style1_best.pth', help='path to save model')
parser.add_argument('--data_root', type=str, default='../../dataset/shape_texture_v2/', help='path to data root')

opt = parser.parse_args(args=[])

# %%
# trained classifier를 load해오기
opt.n_class = 20
model = resnet50(pretrained = True)
    
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, opt.n_class)

model.load_state_dict(torch.load(opt.model_path))
# Out:
# <All keys matched successfully>

# %%
for param in model.parameters():
    param.requires_grad_(False)
model = model.cuda()

# %%
def get_features(image, model):
    # model 레이어별로 feature 뽑아오기 (for content, gram matrix)
    x = image
    features = {}

    x = model.conv1(x)
    x = model.bn1(x)
    x = model.relu(x)
    x = model.maxpool(x)
    i = 0
    
    print(x.shape)

    for name, layer in model.layer1._modules.items():
        x = layer(x)
        i+=1
        features[f"bneck_{name}_{i}"] = x

    for name, layer in model.layer2._modules.items():
        x = layer(x)
        i+=1
        features[f"bneck_{name}_{i}"] = x

    for name, layer in model.layer3._modules.items():
        x = layer(x)
        i+=1
        features[f"bneck_{name}_{i}"] = x

    for name, layer in model.layer4._modules.items():
        x = layer(x)
        i+=1
        features[f"bneck_{name}_{i}"] = x


    return features

# %%
# 생각읋 해보면, 전체 데이터셋에 대해서 할 필요는 없음 -> 데이터 한번 줄이기 (20개의 클래스별로 x 100장씩 -> 2000개씩)
# np.random.seed(10)
# import shutil
# path = '../../dataset/ours_style1_set/train'

# def save_file(class_path, save_path, filenames, start_num, end_num):
#     print(start_num)
#     print(end_num)
#     target_filenames = filenames[start_num:end_num]
#     for target_filename in target_filenames:
#         src = os.path.join(class_path, target_filename)
#         dst = os.path.join(save_path, target_filename)
#         shutil.copy(src, dst)
        
# def split_train_test():
#     for car_class in os.listdir(path):
        
#         car_class_path = os.path.join(path, car_class)
#         car_filenames = os.listdir(car_class_path)
#         train_path = os.path.join('../../dataset/ours_style1_set_100_metric_3/', car_class)

#         if not os.path.exists(train_path):
#             os.makedirs(train_path)

#         save_file(car_class_path, train_path, car_filenames, 0, 10)

# split_train_test()

# %%
# get datasets
test_transforms_option = transforms.Compose([
                    transforms.Resize((256, 256)),
                    transforms.ToTensor(),
                    transforms.Normalize([0.5071, 0.4867, 0.4408], [0.2675, 0.2565, 0.2761])
                ])
test_datasets = torchvision.datasets.ImageFolder(root=opt.data_root, transform = test_transforms_option)
test_loader = torch.utils.data.DataLoader(test_datasets, batch_size = 16, shuffle=False, num_workers = 4)

# %%
i = 0
## 레이어별로 feature 뽑아서 저장
image_features_output = dict()

with torch.no_grad() :
    
    for idx, (input, target) in enumerate(test_loader) :
        input = input.float()
        if torch.cuda.is_available():
            input = input.cuda()
            target = target.cuda()
        
        image_features = get_features(input, model)
        
        if i == 0 :
            for key, item in image_features.items():
                image_features_output[key] = item
        else :
            for key, item in image_features.items() : 
                image_features_output[key] = torch.cat([image_features_output[key], image_features[key]])
            
        i += 1
# Out:
# torch.Size([16, 64, 64, 64])
# torch.Size([16, 64, 64, 64])
# torch.Size([16, 64, 64, 64])
# torch.Size([16, 64, 64, 64])
# torch.Size([16, 64, 64, 64])
# torch.Size([16, 64, 64, 64])
# torch.Size([5, 64, 64, 64])

# %%
## 어떤식으로 저장되었는지 확인
for key, item in image_features_output.items():
    print(key)
    print(item.shape)
    print()
# Out:
# bneck_0_1
# torch.Size([101, 256, 64, 64])
#
# bneck_1_2
# torch.Size([101, 256, 64, 64])
#
# bneck_2_3
# torch.Size([101, 256, 64, 64])
#
# bneck_0_4
# torch.Size([101, 512, 32, 32])
#
# bneck_1_5
# torch.Size([101, 512, 32, 32])
#
# bneck_2_6
# torch.Size([101, 512, 32, 32])
#
# bneck_3_7
# torch.Size([101, 512, 32, 32])
#
# bneck_0_8
# torch.Size([101, 1024, 16, 16])
#
# bneck_1_9
# torch.Size([101, 1024, 16, 16])
#
# bneck_2_10
# torch.Size([101, 1024, 16, 16])
#
# bneck_3_11
# torch.Size([101, 1024, 16, 16])
#
# bneck_4_12
# torch.Size([101, 1024, 16, 16])
#
# bneck_5_13
# torch.Size([101, 1024, 16, 16])
#
# bneck_0_14
# torch.Size([101, 2048, 8, 8])
#
# bneck_1_15
# torch.Size([101, 2048, 8, 8])
#
# bneck_2_16
# torch.Size([101, 2048, 8, 8])

# %%
# content matrix는 higher layer에서 뽑아서 지정
content_mat = image_features_output['bneck_5_13'].cpu().detach().numpy()
content_mat.shape
# Out:
# (101, 1024, 16, 16)

# %%
def gram_matrix(tensor):
    
    # input 이미지의 값을 텐서로 받아온다
    _, d, h, w = tensor.shape
    
    # multiplying the features for each channel을 위해 reshape
    tensor = tensor.reshape(d, h * w)
    
    # gram matrix
    gram = np.matmul(tensor, tensor.T)
    
    return gram

# %%
# lower layer에서 gram matrix를 뽑음 
i = 0

for j in range(content_mat.shape[0]) :
    
    if j % 1000 == 0 :
        print('-- check sample number : ', j)
        
    gram_tmp_output = gram_matrix(image_features_output['bneck_1_2'][j].unsqueeze(0).cpu().detach().numpy())
    gram_tmp_output = np.expand_dims(gram_tmp_output, axis=0)

    if i == 0 :
        gram_output = gram_tmp_output
    else :
        gram_output = np.concatenate((gram_output, gram_tmp_output), axis = 0 )
    i += 1

print(gram_output.shape)
# Out:
# -- check sample number :  0
# (101, 256, 256)

# %%
content_mat.shape
# Out:
# (101, 1024, 16, 16)

# %% [markdown]
# ## gram matrix, content matrix cluster 각각 해보기
# - for outlier 제거

# %%
## content matrix, gram matrix 모두 2d 형태로 변형
gram_output_2d = np.reshape(gram_output, (gram_output.shape[0],(gram_output.shape[1] * gram_output.shape[1] )))
content_output_2d = np.reshape(content_mat, (content_mat.shape[0], (content_mat.shape[1] * content_mat.shape[2] * content_mat.shape[3] )))

print(gram_output_2d.shape)
print(content_output_2d.shape)
# Out:
# (101, 65536)
# (101, 262144)

# %%
# 파일 이름 저장
file_nm_list = list()

for i in range(len(test_datasets.imgs)) : 
    file_nm = test_datasets.imgs[i][0]
    file_nm_list.append(file_nm)

# %%
import pandas as pd 
cluster_df = pd.DataFrame({'file_nm' : file_nm_list})
cluster_df.head()
# Out:
#                                              file_nm
# 0  ../../dataset/shape_texture_v2/airplane/airpla...
# 1  ../../dataset/shape_texture_v2/airplane/airpla...
# 2  ../../dataset/shape_texture_v2/airplane/airpla...
# 3  ../../dataset/shape_texture_v2/airplane/airpla...
# 4  ../../dataset/shape_texture_v2/airplane/airpla...

# %%
# shape에 대한 cluster
from sklearn.cluster import KMeans

k = 10
model = KMeans(n_clusters = k, random_state = 10, max_iter = 1000)
model.fit(content_output_2d)

cluster_df['shape_cluster'] = model.fit_predict(content_output_2d)

# %%
cluster_df['shape_cluster'].value_counts()
# Out:
# 1    82
# 0     4
# 5     3
# 9     3
# 6     2
# 8     2
# 4     2
# 7     1
# 3     1
# 2     1
# Name: shape_cluster, dtype: int64

# %%
# outlier는 삭제해볼까
outlier_list = list()

outlier_list.extend(cluster_df[cluster_df['shape_cluster'] == 2]['file_nm'].to_list())
outlier_list.extend(cluster_df[cluster_df['shape_cluster'] == 3]['file_nm'].to_list())
outlier_list.extend(cluster_df[cluster_df['shape_cluster'] == 7]['file_nm'].to_list())
outlier_list.extend(cluster_df[cluster_df['shape_cluster'] == 4]['file_nm'].to_list())
outlier_list.extend(cluster_df[cluster_df['shape_cluster'] == 8]['file_nm'].to_list())
outlier_list.extend(cluster_df[cluster_df['shape_cluster'] == 6]['file_nm'].to_list())

# %%
outlier_list
# Out:
# ['../../dataset/shape_texture_v2/frog/frog_1102.png',
#  '../../dataset/shape_texture_v2/deer/deer_1015.png',
#  '../../dataset/shape_texture_v2/cat_stylized/cat_1765_stylized_Ink and wash painting_Ink and wash painting_13489.jpg',
#  '../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg',
#  '../../dataset/shape_texture_v2/ship/ship_0837.png',
#  '../../dataset/shape_texture_v2/airplane_stylized/airplane_0680_stylized_Ink and wash painting_Ink and wash painting_102302.jpg',
#  '../../dataset/shape_texture_v2/truck_stylized/truck_1248_stylized_Ink and wash painting_Ink and wash painting_18777.jpg',
#  '../../dataset/shape_texture_v2/airplane/airplane_0011.png',
#  '../../dataset/shape_texture_v2/cat/cat_0131.png']

# %%
# shape에 대한 cluster
k = 5
model = KMeans(n_clusters = k, random_state = 10, max_iter = 1000)
model.fit(gram_output_2d)

cluster_df['texture_cluster'] = model.fit_predict(gram_output_2d)

# %%
cluster_df['texture_cluster'].value_counts()
# Out:
# 1    50
# 3    24
# 0    19
# 2     6
# 4     2
# Name: texture_cluster, dtype: int64

# %%
# outlier는 삭제해볼까
outlier_texture_list = list()
outlier_texture_list.extend(cluster_df[cluster_df['texture_cluster'] == 4]['file_nm'].to_list())
outlier_texture_list
# Out:
# ['../../dataset/shape_texture_v2/airplane/airplane_0795.png',
#  '../../dataset/shape_texture_v2/cat/cat_0659.png']

# %% [markdown]
# ## distance 기반으로 pair
# - (1) shape은 다르고 texture는 같은 pair -> 완료
# - (2) shape은 같고 texture는 다른 pair

# %%
# shape은 다르고 texture는 같은 것 pair (완료)
for i in range(len(cluster_df)):
    print('############################################## ')
    
    ## pair의 첫번째 img
    print(cluster_df['file_nm'][i])
    
    content_mat_i = content_mat[i]
    gram_mat_i = gram_output[i]
    
    loss_list = list()
    
    ## 전체 이미지들과 shape, texture distance 구해서 계산
    for j in range(len(cluster_df)):
        
        content_mat_j = content_mat[j]
        gram_mat_j = gram_output[j]
        
        # shape, texture loss
        loss_shape = ( content_mat_i - content_mat_j ) ** 2
        loss_texture = ( gram_mat_i - gram_mat_j ) ** 2

        # normalize (texture scale >>> shape scale)
        normalized_shape = loss_shape / np.sqrt(np.sum(loss_shape))
        normalized_texture = loss_texture / np.sqrt(np.sum(loss_texture))
        
        if i == j :
            # 자기 자신은 제외
            loss = 100000000000
        else : 
            loss = np.mean(normalized_texture) ** 2 / np.mean(normalized_shape)
        loss_list.append(loss)
    
    ## distance 제일 작은 것 index
    min_idx = np.argmin(np.array(loss_list))
    
    ## pair의 두번째 이미지
    shape_distance_min = cluster_df['file_nm'][min_idx]#[min_idx+(i+1)]
    
    
    print(shape_distance_min)
    print(np.mean(loss_list[min_idx]))
    print()
# Out:
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_0011.png
# ../../dataset/shape_texture_v2/frog/frog_1102.png
# 8320.596417628627
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_0680.png
# ../../dataset/shape_texture_v2/cat/cat_1210.png
# 6346.03515147339
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_0721.png
# /tmp/ipykernel_8393/3431351782.py:24: RuntimeWarning: invalid value encountered in true_divide
#   normalized_shape = loss_shape / np.sqrt(np.sum(loss_shape))
# /tmp/ipykernel_8393/3431351782.py:25: RuntimeWarning: invalid value encountered in true_divide
#   normalized_texture = loss_texture / np.sqrt(np.sum(loss_texture))
# ../../dataset/shape_texture_v2/dog/dog_2070.png
# 10415.133989237793
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_0795.png
# ../../dataset/shape_texture_v2/automobile/automobile_4109.png
# 75524.37262889907
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_1098.png
# ../../dataset/shape_texture_v2/dog/dog_0238.png
# 8090.447497233344
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_4897.png
# ../../dataset/shape_texture_v2/dog/dog_0238.png
# 12070.543490819455
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0601_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/ship_stylized/ship_3167_stylized_Ink and wash painting_Ink and wash painting_100664.jpg
# 2113.4882455013444
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0671_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_1266_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# 6058.6284885148525
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0680_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0671_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# 6360.308528719588
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_1266_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# ../../dataset/shape_texture_v2/ship_stylized/ship_0781_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# 5495.284274657892
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_2191_stylized_Ink and wash painting_Ink and wash painting_1252.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_3533_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# 3352.9196379010305
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_0136.png
# ../../dataset/shape_texture_v2/truck/truck_1346.png
# 7303.154091709868
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_0239.png
# ../../dataset/shape_texture_v2/ship/ship_0837.png
# 8744.127819471036
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_0638.png
# ../../dataset/shape_texture_v2/horse/horse_0686.png
# 3402.0836911647607
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_1199.png
# ../../dataset/shape_texture_v2/frog/frog_0123.png
# 7225.316343289891
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_2973.png
# ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# 34476.646562821064
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_4109.png
# ../../dataset/shape_texture_v2/ship/ship_0837.png
# 30269.858104739596
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0175_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/bird_stylized/bird_1545_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# 2066.2189842701105
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0465_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# ../../dataset/shape_texture_v2/cat_stylized/cat_2314_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# 2212.6443363186495
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1039_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_12945.jpg
# 12936.271315548182
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# ../../dataset/shape_texture_v2/cat/cat_0131.png
# 27150.79719190964
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_2800_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0680_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# 12822.449023634439
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0046.png
# ../../dataset/shape_texture_v2/dog/dog_2070.png
# 2604.5962119617056
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# ../../dataset/shape_texture_v2/bird/bird_0752.png
# 3608.8993544897785
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0385.png
# ../../dataset/shape_texture_v2/bird/bird_0638.png
# 18447.421664620855
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0638.png
# ../../dataset/shape_texture_v2/dog/dog_1955.png
# 4658.041101096506
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0752.png
# ../../dataset/shape_texture_v2/deer/deer_0890.png
# 2509.650461751882
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_0219_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/frog_stylized/frog_1760_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# 1889.962896672897
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_0304_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# ../../dataset/shape_texture_v2/bird_stylized/bird_2943_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# 877.9667225694989
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_1545_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0175_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# 2066.2189842701105
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_1919_stylized_Ink and wash painting_Ink and wash painting_16356.jpg
# ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# 6488.266714428735
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_2943_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# ../../dataset/shape_texture_v2/bird_stylized/bird_0304_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# 877.9667225694989
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_0131.png
# ../../dataset/shape_texture_v2/truck/truck_1845.png
# 11882.823575044162
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_0440.png
# ../../dataset/shape_texture_v2/deer/deer_0342.png
# 8576.53476013361
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_0659.png
# ../../dataset/shape_texture_v2/automobile/automobile_4109.png
# 45708.02923003583
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_1210.png
# ../../dataset/shape_texture_v2/frog/frog_1036.png
# 4366.286510021543
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_1550.png
# ../../dataset/shape_texture_v2/truck/truck_1665.png
# 4861.637989334783
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_12945.jpg
# ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# 6951.921375048358
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_3533_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# 1886.9819196732496
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_1765_stylized_Ink and wash painting_Ink and wash painting_13489.jpg
# ../../dataset/shape_texture_v2/frog_stylized/frog_2416_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
# 11341.43952239862
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_2314_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0465_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# 2212.6443363186495
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_3704_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/bird_stylized/bird_1545_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# 4583.846437228596
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_0071.png
# ../../dataset/shape_texture_v2/automobile/automobile_0638.png
# 6021.324806864495
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_0342.png
# ../../dataset/shape_texture_v2/bird_stylized/bird_1545_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# 6784.581198120685
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_0826.png
# ../../dataset/shape_texture_v2/bird_stylized/bird_0219_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# 5611.853032812587
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_0890.png
# ../../dataset/shape_texture_v2/bird/bird_0752.png
# 2509.650461751882
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_1015.png
# ../../dataset/shape_texture_v2/frog/frog_1102.png
# 4181.693102495504
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_0595_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# ../../dataset/shape_texture_v2/ship_stylized/ship_0781_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# 3523.4797795715335
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_3194_stylized_Ink and wash painting_Ink and wash painting_100378.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_2325_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# 6625.90454101565
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_3878_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# ../../dataset/shape_texture_v2/frog_stylized/frog_3322_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# 2481.0350065090106
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_4985_stylized_Ink and wash painting_Ink and wash painting_14217.jpg
# ../../dataset/shape_texture_v2/dog_stylized/dog_1617_stylized_Ink and wash painting_Ink and wash painting_16162.jpg
# 5621.942428696288
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_4985_stylized_Ink and wash painting_Ink and wash painting_18808.jpg
# ../../dataset/shape_texture_v2/dog_stylized/dog_3703_stylized_Ink and wash painting_Ink and wash painting_18808.jpg
# 4531.2782121018545
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# ../../dataset/shape_texture_v2/dog/dog_2070.png
# 3864.725924612089
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_0238.png
# ../../dataset/shape_texture_v2/dog/dog_0588.png
# 3200.373871804581
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_0588.png
# ../../dataset/shape_texture_v2/dog/dog_0238.png
# 3200.373871804581
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_1955.png
# ../../dataset/shape_texture_v2/bird/bird_0638.png
# 4658.041101096506
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_2070.png
# ../../dataset/shape_texture_v2/bird/bird_0046.png
# 2604.5962119617056
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_4400.png
# ../../dataset/shape_texture_v2/truck/truck_1665.png
# 4693.260482185801
#
# ##############################################
# ../../dataset/shape_texture_v2/dog_stylized/dog_1617_stylized_Ink and wash painting_Ink and wash painting_16162.jpg
# ../../dataset/shape_texture_v2/deer_stylized/deer_4985_stylized_Ink and wash painting_Ink and wash painting_14217.jpg
# 5621.942428696288
#
# ##############################################
# ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_2984_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# 2841.614207688751
#
# ##############################################
# ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# ../../dataset/shape_texture_v2/bird_stylized/bird_1919_stylized_Ink and wash painting_Ink and wash painting_16356.jpg
# 6488.266714428735
#
# ##############################################
# ../../dataset/shape_texture_v2/dog_stylized/dog_3703_stylized_Ink and wash painting_Ink and wash painting_18808.jpg
# ../../dataset/shape_texture_v2/deer_stylized/deer_4985_stylized_Ink and wash painting_Ink and wash painting_18808.jpg
# 4531.2782121018545
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_0090.png
# ../../dataset/shape_texture_v2/bird/bird_0638.png
# 8353.154227058718
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_0123.png
# ../../dataset/shape_texture_v2/dog/dog_4400.png
# 5313.301431310561
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_1036.png
# ../../dataset/shape_texture_v2/truck/truck_1346.png
# 4006.3274161071126
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_1102.png
# ../../dataset/shape_texture_v2/ship/ship_0837.png
# 3716.01162068008
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_1365.png
# ../../dataset/shape_texture_v2/horse/horse_0236.png
# 3972.985324072564
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_1371_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/frog_stylized/frog_1760_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# 586.1460833511607
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_1760_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_2325_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# 379.69822269365704
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_2416_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_3265_stylized_Ink and wash painting_Ink and wash painting_102147.jpg
# 4862.254848728363
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_3257_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# ../../dataset/shape_texture_v2/ship_stylized/ship_0781_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# 4282.739012631326
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_3322_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# ../../dataset/shape_texture_v2/bird_stylized/bird_2943_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# 1316.8087351623253
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_0236.png
# ../../dataset/shape_texture_v2/frog/frog_1365.png
# 3972.985324072564
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_0679.png
# ../../dataset/shape_texture_v2/dog/dog_2070.png
# 12138.856824332242
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_0686.png
# ../../dataset/shape_texture_v2/automobile/automobile_0638.png
# 3402.0836911647607
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_1007.png
# ../../dataset/shape_texture_v2/ship/ship_3410.png
# 8826.321179758315
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_1441.png
# ../../dataset/shape_texture_v2/ship/ship_0837.png
# 8754.46048006397
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_2325_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/frog_stylized/frog_1760_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# 379.69822269365704
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_2984_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# 2841.614207688751
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_3265_stylized_Ink and wash painting_Ink and wash painting_102147.jpg
# ../../dataset/shape_texture_v2/frog_stylized/frog_2416_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
# 4862.254848728363
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_3414_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0680_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# 8670.244417168335
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_3533_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# 1886.9819196732496
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_0097.png
# ../../dataset/shape_texture_v2/ship/ship_3410.png
# 5468.525014264981
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_0165.png
# ../../dataset/shape_texture_v2/truck/truck_0171.png
# 4913.296340682527
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_0837.png
# ../../dataset/shape_texture_v2/truck/truck_1845.png
# 1945.3147574327934
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_1134.png
# ../../dataset/shape_texture_v2/bird_stylized/bird_0304_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# 4598.893385160107
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_3410.png
# ../../dataset/shape_texture_v2/ship/ship_0097.png
# 5468.525014264981
#
# ##############################################
# ../../dataset/shape_texture_v2/ship_stylized/ship_0541_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/frog_stylized/frog_1371_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# 1869.9751936040877
#
# ##############################################
# ../../dataset/shape_texture_v2/ship_stylized/ship_0781_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# ../../dataset/shape_texture_v2/deer_stylized/deer_0595_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# 3523.4797795715335
#
# ##############################################
# ../../dataset/shape_texture_v2/ship_stylized/ship_3167_stylized_Ink and wash painting_Ink and wash painting_100664.jpg
# ../../dataset/shape_texture_v2/ship_stylized/ship_4204_stylized_Ink and wash painting_Ink and wash painting_100664.jpg
# 755.6194589914626
#
# ##############################################
# ../../dataset/shape_texture_v2/ship_stylized/ship_4204_stylized_Ink and wash painting_Ink and wash painting_100664.jpg
# ../../dataset/shape_texture_v2/ship_stylized/ship_3167_stylized_Ink and wash painting_Ink and wash painting_100664.jpg
# 755.6194589914626
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_0035.png
# ../../dataset/shape_texture_v2/dog/dog_2070.png
# 14712.900446333471
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_0171.png
# ../../dataset/shape_texture_v2/ship/ship_0165.png
# 4913.296340682527
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_1346.png
# ../../dataset/shape_texture_v2/frog/frog_1036.png
# 4006.3274161071126
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_1665.png
# ../../dataset/shape_texture_v2/dog/dog_4400.png
# 4693.260482185801
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_1845.png
# ../../dataset/shape_texture_v2/ship/ship_0837.png
# 1945.3147574327934
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_0681_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# ../../dataset/shape_texture_v2/truck_stylized/truck_2003_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# 876.9637014662029
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_0713_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/bird_stylized/bird_0219_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# 3572.769070276172
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_1248_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_3265_stylized_Ink and wash painting_Ink and wash painting_102147.jpg
# 6820.740950860286
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_2003_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# ../../dataset/shape_texture_v2/truck_stylized/truck_0681_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# 876.9637014662029
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_3893_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/automobile/automobile_0638.png
# 4720.089025987863

# %%
# shape은 같고 texture는 다른 것 pair -> 안됨
for i in range(len(cluster_df)):
    if cluster_df['file_nm'][i] in outlier_texture_list : 
        continue
    else :
    
        print('############################################## ')

        ## pair의 첫번째 img
        print(cluster_df['file_nm'][i])

        content_mat_i = content_mat[i]
        gram_mat_i = gram_output[i]

        loss_list = list()

        ## 전체 이미지들과 shape, texture distance 구해서 계산
        for j in range(len(cluster_df)):
            
            if cluster_df['file_nm'][j] in outlier_texture_list : 
                continue 
            else : 
                content_mat_j = content_mat[j]
                gram_mat_j = gram_output[j]

                # shape, texture loss
                loss_shape = ( content_mat_i - content_mat_j ) ** 2
                loss_texture = ( gram_mat_i - gram_mat_j ) ** 2

                # normalize (texture scale >>> shape scale)
                normalized_shape = loss_shape / np.sqrt(np.sum(loss_shape))
                normalized_texture = loss_texture / np.sqrt(np.sum(loss_texture))

                if i == j :
                    # 자기 자신은 제외
                    loss = 100000000000
                else : 
                    loss = np.mean(normalized_shape) **2 / np.mean(normalized_texture)
                loss_list.append(loss)
                
        if cluster_df['file_nm'][j] in outlier_texture_list : 
            continue 
        else : 
            ## distance 제일 작은 것 index
            min_idx = np.argmin(np.array(loss_list))

            ## pair의 두번째 이미지
            shape_distance_min = cluster_df['file_nm'][min_idx]#[min_idx+(i+1)]


            print(shape_distance_min)
            print(np.mean(loss_list[min_idx]))
            print()
# Out:
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_0011.png
# ../../dataset/shape_texture_v2/bird_stylized/bird_2943_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# 1.7832230932216052e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_0680.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.7112367860550113e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_0721.png
# /tmp/ipykernel_8393/1793145751.py:31: RuntimeWarning: invalid value encountered in true_divide
#   normalized_shape = loss_shape / np.sqrt(np.sum(loss_shape))
# /tmp/ipykernel_8393/1793145751.py:32: RuntimeWarning: invalid value encountered in true_divide
#   normalized_texture = loss_texture / np.sqrt(np.sum(loss_texture))
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.2039606037459374e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_1098.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 3.9725533497584666e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane/airplane_4897.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.6090372015085863e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0601_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 5.027463078070175e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0671_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_3414_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# 1.259761086781151e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0680_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_12945.jpg
# 1.471052016341476e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_1266_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# ../../dataset/shape_texture_v2/horse_stylized/horse_3414_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# 1.054045325398202e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_2191_stylized_Ink and wash painting_Ink and wash painting_1252.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.2964040989238344e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_0136.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 5.002498910888287e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_0239.png
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 5.773745665040624e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_0638.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.800723286267228e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_1199.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 7.233148137720727e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_2973.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 3.8040766596568903e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile/automobile_4109.png
# ../../dataset/shape_texture_v2/ship/ship_0165.png
# 9.967542596003832e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0175_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.5712386506534584e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0465_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.028116482014279e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1039_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 5.326517307846743e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# ../../dataset/shape_texture_v2/ship/ship_0165.png
# 1.2950116808447495e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_2800_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 3.400681324526225e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0046.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0465_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# 1.5542847596380125e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 3.8568728959098814e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0385.png
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 3.150368929840424e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0638.png
# ../../dataset/shape_texture_v2/automobile/automobile_1199.png
# 1.522437795580353e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/bird/bird_0752.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 3.962776097529366e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_0219_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.58077038948702e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_0304_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.3596018594999883e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_1545_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.7512519050364025e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_1919_stylized_Ink and wash painting_Ink and wash painting_16356.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.833914860503916e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_2943_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.6767335197161634e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_0131.png
# ../../dataset/shape_texture_v2/cat/cat_1550.png
# 1.5165734751586281e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_0440.png
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.747292356339241e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_1210.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.12243337376817e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/cat/cat_1550.png
# ../../dataset/shape_texture_v2/automobile/automobile_1199.png
# 6.506893173552436e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_12945.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 6.062648055025291e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 3.884340763389774e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_1765_stylized_Ink and wash painting_Ink and wash painting_13489.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 1.366641130234606e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_2314_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 6.150996636084955e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_3704_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.816645232997425e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_0071.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.373231064344332e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_0342.png
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.279207512757592e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_0826.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.6619525908548716e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_0890.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.045447975086253e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer/deer_1015.png
# ../../dataset/shape_texture_v2/horse/horse_0679.png
# 1.4809739172077465e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_0595_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 8.722215349796453e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_3194_stylized_Ink and wash painting_Ink and wash painting_100378.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 3.648105488612743e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_3878_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.680383029447778e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_4985_stylized_Ink and wash painting_Ink and wash painting_14217.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 9.900424744473018e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_4985_stylized_Ink and wash painting_Ink and wash painting_18808.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 1.0170387235405685e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 5.35806224031774e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_0238.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 3.689753574089565e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_0588.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 3.150368929840424e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_1955.png
# ../../dataset/shape_texture_v2/automobile/automobile_1199.png
# 7.221593192450766e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_2070.png
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 2.096115236672899e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/dog/dog_4400.png
# ../../dataset/shape_texture_v2/automobile/automobile_1199.png
# 5.648085392155843e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/dog_stylized/dog_1617_stylized_Ink and wash painting_Ink and wash painting_16162.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 8.618023932516673e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.597841482790336e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 1.604928141628182e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/dog_stylized/dog_3703_stylized_Ink and wash painting_Ink and wash painting_18808.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 6.055074668116704e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_0090.png
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 3.442858613425625e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_0123.png
# ../../dataset/shape_texture_v2/automobile/automobile_2973.png
# 1.337333100864757e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_1036.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.173500101617561e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_1102.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0465_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# 3.1093692676581864e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/frog/frog_1365.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0465_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# 1.4857211294281043e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_1371_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.6462245031994635e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_1760_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 5.084065933491704e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_2416_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.792822548104292e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_3257_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.6521932720161584e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/frog_stylized/frog_3322_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.904970109061429e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_0236.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0465_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# 8.032088124007928e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_0679.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.793811080043768e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_0686.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.483650650100039e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_1007.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 3.568043533811384e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse/horse_1441.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 5.640783825376127e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_2325_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.474783862800884e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_2984_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.6795855400710487e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_3265_stylized_Ink and wash painting_Ink and wash painting_102147.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 1.0692346863714308e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_3414_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.948479071498134e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/horse_stylized/horse_3533_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.2289816027197e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_0097.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 4.133905142156749e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_0165.png
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 8.379954135887167e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_0837.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1039_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# 1.688624262060884e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_1134.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 6.969149792798598e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/ship/ship_3410.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 3.746560165724275e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/ship_stylized/ship_0541_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/dog/dog_0017.png
# 4.822692382927295e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/ship_stylized/ship_0781_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 7.041853476155037e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/ship_stylized/ship_3167_stylized_Ink and wash painting_Ink and wash painting_100664.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 6.082045744535716e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/ship_stylized/ship_4204_stylized_Ink and wash painting_Ink and wash painting_100664.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 5.251015683760877e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_0035.png
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 6.87213468626892e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_0171.png
# ../../dataset/shape_texture_v2/deer_stylized/deer_4985_stylized_Ink and wash painting_Ink and wash painting_18808.jpg
# 8.714010722957265e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_1346.png
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 5.571759253768956e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_1665.png
# ../../dataset/shape_texture_v2/automobile/automobile_1199.png
# 6.83828634498007e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/truck/truck_1845.png
# ../../dataset/shape_texture_v2/ship/ship_0165.png
# 1.1899499636762672e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_0681_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 8.524852512670026e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_0713_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 4.247006754953953e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_1248_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 1.4608018609859235e-06
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_2003_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# 6.984857619965433e-07
#
# ##############################################
# ../../dataset/shape_texture_v2/truck_stylized/truck_3893_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# 5.979239927284676e-07

# %% [markdown]
# ## 클러스터 상에서의 값을 활용하는 경우
# - shape 자체가 클러스터에서 제대로 안묶여서 사용하기 어려울듯

# %%
## 클러스터를 사용하는 경우, 같은 shape으로 나온 것중 distance가 가장 먼것을 선정해보기
pair_nm_list = list()

for i in range(len(cluster_df)) :
    
    if i % 500 == 0 :
        print('-- check iteration: ', i)
    
    # 같은 shape으로 나온 샘플들 선정
    shape_class = cluster_df['shape_cluster'][i]
    same_shape_df = cluster_df[cluster_df['shape_cluster'] == shape_class]
    
    # 이 샘플들과의 texture distance를 구함
    loss_list = list()
    for k in same_shape_df.index : 
        loss = 0
        
        if i == k :
            continue 
        else : 
    
            ## 레이어별로 loss를 전부 계산
            for layer_nm in image_features_output.keys() :
                loss = np.mean(gram_matrix(image_features_output[layer_nm][i].unsqueeze(0).cpu().detach().numpy()) - gram_matrix(image_features_output[layer_nm][k].unsqueeze(0).cpu().detach().numpy())) **2
                loss += loss
            loss_list.append(loss)
    
    if len(loss_list) == 0:
        pair_nm_list.append('0')
    else : 
        tmp_idx = np.argmin(np.array(loss_list))        
        pair_idx = same_shape_df.index[tmp_idx]  
    
        # 제일 가까운 샘플 선정해서 df에 추가해보기
        pair_nm_list.append(cluster_df['file_nm'][pair_idx])

# %%
cluster_df['pair_shape'] = pair_nm_list
cluster_df.head(10)

# %%
for j in range(content_mat.shape[0]) :
    
    if j % 1000 == 0 :
        print('-- check sample number : ', j)
        
    gram_tmp_output = gram_matrix(image_features_output['bneck_1_2'][j].unsqueeze(0).cpu().detach().numpy())
    gram_tmp_output = np.expand_dims(gram_tmp_output, axis=0)

    if i == 0 :
        gram_output = gram_tmp_output
    else :
        gram_output = np.concatenate((gram_output, gram_tmp_output), axis = 0 )
    i += 1

print(gram_output.shape)

# %%
k = 2
model = KMeans(n_clusters = k, random_state = 10)
model.fit(gram_output_2d)

cluster_df['texture_cluster'] = model.fit_predict(gram_output_2d)

# %%
# 이렇게 되면 한 이미지에서 shape에 대한 cluster, texture에 대한 cluster가 나오게됨
cluster_df.head()
# Out:
#                                              file_nm  shape_cluster  \
# 0  ../../dataset/ours_style1_set_100_metric_3/air...              9
# 1  ../../dataset/ours_style1_set_100_metric_3/air...              9
# 2  ../../dataset/ours_style1_set_100_metric_3/air...              9
# 3  ../../dataset/ours_style1_set_100_metric_3/air...              0
# 4  ../../dataset/ours_style1_set_100_metric_3/air...              9
#
#    texture_cluster
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
cluster_df.to_csv('result_texture_shape_2.csv', index =False)

# %%
gram_output.shape
# Out:
# (2000, 256, 256)

# %%
# 각 texture별로 돌면서, 과연 차이가 있는지 확인하기
for i in range(0, content_mat.shape[0]) :
    print('###########################################################')
    print(file_nm_list[i])
    
    shape_distance_tmp_list = list() # ith 이미지에서 제일 shape이 먼 것 확인
    texture_distance_tmp_list = list()
    
    for j in range(i+1, content_mat.shape[0]) :
        
        # 여기서는 shape을 구하고
        shape_distance = np.mean((content_mat[i] - content_mat[j]) **2) # l2 distance
        shape_distance_tmp_list.append(shape_distance)
    
        # 여기서는 texture를 구한다
        texture_distance = np.mean((gram_output[i] - gram_output[j]) **2)
        texture_distance_tmp_list.append(texture_distance)
        
    # 최종적으로는 score 확인
    score_list = list()
    
    for k in range(len(shape_distance_tmp_list)) :
        score_list.append(shape_distance_tmp_list[k] / texture_distance_tmp_list[k])
        
    ## score이 제일 큰건 shape pair
    shape_pair_idx = np.argmax(np.array(score_list)) + (i+1)
    print('> shape pair : ', file_nm_list[shape_pair_idx])
    
    ## score이 제일 작은건 texture pair
    texture_pair_idx = np.argmin(np.array(score_list)) + (i+1)
    print('> texture pair : ', file_nm_list[texture_pair_idx])
    print()
# Out:
# ###########################################################
# ../../dataset/shape_texture_v2/airplane/airplane_0011.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/airplane/airplane_0795.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane/airplane_0680.png
# > shape pair :  ../../dataset/shape_texture_v2/cat/cat_1210.png
# > texture pair :  ../../dataset/shape_texture_v2/airplane/airplane_0795.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane/airplane_0721.png
# > shape pair :  ../../dataset/shape_texture_v2/dog/dog_2070.png
# > texture pair :  ../../dataset/shape_texture_v2/airplane/airplane_0795.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane/airplane_0795.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/bird/bird_0385.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane/airplane_1098.png
# > shape pair :  ../../dataset/shape_texture_v2/ship/ship_1134.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane/airplane_4897.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_0123.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0601_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# > shape pair :  ../../dataset/shape_texture_v2/ship_stylized/ship_3167_stylized_Ink and wash painting_Ink and wash painting_100664.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0671_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# > shape pair :  ../../dataset/shape_texture_v2/airplane_stylized/airplane_0680_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_0680_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# > shape pair :  ../../dataset/shape_texture_v2/ship_stylized/ship_0781_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_1266_stylized_Ink and wash painting_Ink and wash painting_18819.jpg
# > shape pair :  ../../dataset/shape_texture_v2/ship_stylized/ship_0781_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/airplane_stylized/airplane_2191_stylized_Ink and wash painting_Ink and wash painting_1252.jpg
# > shape pair :  ../../dataset/shape_texture_v2/horse_stylized/horse_3533_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile/automobile_0136.png
# > shape pair :  ../../dataset/shape_texture_v2/truck/truck_1346.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile/automobile_0239.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile/automobile_0638.png
# > shape pair :  ../../dataset/shape_texture_v2/horse/horse_0686.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile/automobile_1199.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_0123.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile/automobile_2973.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile/automobile_4109.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/ship/ship_1134.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0175_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# > shape pair :  ../../dataset/shape_texture_v2/bird_stylized/bird_1545_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_0465_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# > shape pair :  ../../dataset/shape_texture_v2/cat_stylized/cat_2314_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1039_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# > shape pair :  ../../dataset/shape_texture_v2/truck_stylized/truck_1248_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_1455_stylized_Ink and wash painting_Ink and wash painting_102833.jpg
# > shape pair :  ../../dataset/shape_texture_v2/cat/cat_0131.png
# > texture pair :  ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_189.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/automobile_stylized/automobile_2800_stylized_Ink and wash painting_Ink and wash painting_102302.jpg
# > shape pair :  ../../dataset/shape_texture_v2/dog/dog_2070.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird/bird_0046.png
# > shape pair :  ../../dataset/shape_texture_v2/dog/dog_2070.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird/bird_0210.png
# > shape pair :  ../../dataset/shape_texture_v2/bird/bird_0752.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird/bird_0385.png
# > shape pair :  ../../dataset/shape_texture_v2/bird/bird_0638.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird/bird_0638.png
# > shape pair :  ../../dataset/shape_texture_v2/dog/dog_1955.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird/bird_0752.png
# > shape pair :  ../../dataset/shape_texture_v2/deer/deer_0890.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_0219_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# > shape pair :  ../../dataset/shape_texture_v2/frog_stylized/frog_1760_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_0304_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# > shape pair :  ../../dataset/shape_texture_v2/bird_stylized/bird_2943_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_1545_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# > shape pair :  ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_1919_stylized_Ink and wash painting_Ink and wash painting_16356.jpg
# > shape pair :  ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/bird_stylized/bird_2943_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# > shape pair :  ../../dataset/shape_texture_v2/frog_stylized/frog_3322_stylized_Ink and wash painting_Ink and wash painting_12483.jpg
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat/cat_0131.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_189.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat/cat_0440.png
# > shape pair :  ../../dataset/shape_texture_v2/dog/dog_2070.png
# > texture pair :  ../../dataset/shape_texture_v2/cat/cat_0659.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat/cat_0659.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/dog/dog_0588.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat/cat_1210.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1036.png
# > texture pair :  ../../dataset/shape_texture_v2/horse_stylized/horse_3414_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat/cat_1550.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/horse_stylized/horse_3414_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_12945.jpg
# > shape pair :  ../../dataset/shape_texture_v2/dog_stylized/dog_3638_stylized_Ink and wash painting_Ink and wash painting_13532.jpg
# > texture pair :  ../../dataset/shape_texture_v2/frog/frog_0090.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_0826_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# > shape pair :  ../../dataset/shape_texture_v2/horse_stylized/horse_3533_stylized_Ink and wash painting_Ink and wash painting_189.jpg
# > texture pair :  ../../dataset/shape_texture_v2/frog_stylized/frog_2416_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_1765_stylized_Ink and wash painting_Ink and wash painting_13489.jpg
# > shape pair :  ../../dataset/shape_texture_v2/frog_stylized/frog_2416_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
# > texture pair :  ../../dataset/shape_texture_v2/deer_stylized/deer_3194_stylized_Ink and wash painting_Ink and wash painting_100378.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_2314_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
# > shape pair :  ../../dataset/shape_texture_v2/deer_stylized/deer_0595_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# > texture pair :  ../../dataset/shape_texture_v2/ship/ship_0097.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/cat_stylized/cat_3704_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# > shape pair :  ../../dataset/shape_texture_v2/horse_stylized/horse_2984_stylized_Ink and wash painting_Ink and wash painting_12129.jpg
# > texture pair :  ../../dataset/shape_texture_v2/dog/dog_0588.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/deer/deer_0071.png
# > shape pair :  ../../dataset/shape_texture_v2/ship_stylized/ship_0541_stylized_Ink and wash painting_Ink and wash painting_15469.jpg
# > texture pair :  ../../dataset/shape_texture_v2/frog_stylized/frog_2416_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/deer/deer_0342.png
# > shape pair :  ../../dataset/shape_texture_v2/dog/dog_2070.png
# > texture pair :  ../../dataset/shape_texture_v2/dog/dog_0588.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/deer/deer_0826.png
# > shape pair :  ../../dataset/shape_texture_v2/truck/truck_1346.png
# > texture pair :  ../../dataset/shape_texture_v2/frog_stylized/frog_2416_stylized_Ink and wash painting_Ink and wash painting_18777.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/deer/deer_0890.png
# > shape pair :  ../../dataset/shape_texture_v2/horse/horse_0686.png
# > texture pair :  ../../dataset/shape_texture_v2/horse_stylized/horse_3414_stylized_Ink and wash painting_Ink and wash painting_102642.jpg
#
# ###########################################################
# ../../dataset/shape_texture_v2/deer/deer_1015.png
# > shape pair :  ../../dataset/shape_texture_v2/frog/frog_1102.png
# > texture pair :  ../../dataset/shape_texture_v2/dog/dog_0588.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_0595_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# > shape pair :  ../../dataset/shape_texture_v2/ship_stylized/ship_0781_stylized_Ink and wash painting_Ink and wash painting_13714.jpg
# > texture pair :  ../../dataset/shape_texture_v2/horse/horse_1007.png
#
# ###########################################################
# ../../dataset/shape_texture_v2/deer_stylized/deer_3194_stylized_Ink and wash painting_Ink and wash painting_100378.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       7 texture_distance_tmp_list = list()
#       9 for j in range(i+1, content_mat.shape[0]) :
#      10
#      11     # 여기서는 shape을 구하고
# ---> 12     shape_distance = np.mean((content_mat[i] - content_mat[j]) **2) # l2 distance
#      13     shape_distance_tmp_list.append(shape_distance)
#      15     # 여기서는 texture를 구한다
#
# KeyboardInterrupt:

# %%
print(np.mean((gram_output[0] - gram_output[1]) **2))
print(file_nm_list[0], file_nm_list[1] )
# Out:
# 10893.779
# ../../dataset/ours_style1_set_100_metric/airplane/airplane_0011.png ../../dataset/ours_style1_set_100_metric/airplane/airplane_0035.png

# %%
print(np.mean((gram_output[0] - gram_output[2]) **2))
print(file_nm_list[0], file_nm_list[2] )
# Out:
# 11537.609
# ../../dataset/ours_style1_set_100_metric/airplane/airplane_0011.png ../../dataset/ours_style1_set_100_metric/airplane/airplane_0093.png

# %%
print(np.mean((gram_output[0] - gram_output[499]) **2))
print(file_nm_list[0], file_nm_list[499] )
# Out:
# 12462.594
# ../../dataset/ours_style1_set_100_metric/airplane/airplane_0011.png ../../dataset/ours_style1_set_100_metric/bird/bird_4951.png

# %%
# step1. 같은 shape이되 다른 texture를 가진 것 뽑아보기

# %%
# step2. 같은 texture이되, 다른 shape을 가진것 뽑아보기
